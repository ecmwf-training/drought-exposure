# %% [markdown]
# # Explanation

# %% [markdown]
# Welcome to the explanation collection!
#
# Here you'll find some background information around drought-related risks under climate.
#
# - [About the hazard: drought](./explanations/what_is_drought.md)
# - [Exposure in the drought context](./explanations/exposure.md)
# - [Vulnerability in the drought context](./explanations/vulnerability.md)
# - [Estimating drought risk](./explanations/drought_risk.md)
