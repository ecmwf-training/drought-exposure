# %% [markdown]
# # Explanation

# %% [markdown]
# Here you'll find some background information around drought-related impacts and risks.
#
# - [Drought has different faces](./explanations/what_is_drought.md)
# - [Drouhgt as a hazard](./explanations/hazard.md)
# - [Drought exposure](./explanations/exposure.md)
# - [Drought vulnerability](./explanations/vulnerability.md)
# - [Drought indices](./explanations/indices.md)
# - [Drought risk estimation](./explanations/drought_risk.md)
# - [Drought interpretation](./explanations/interpretation.md)
